# %% [markdown]
# <a href="https://colab.research.google.com/github/RikutoUehara/Python-Study-2026/blob/main/lesson0426.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
total = 0
i = 10
while i < 21:
  total += i
  i += 1
print(total)
# Out:
# 165

# %%
total = 0
for i in range(10,21):
  total += i
print(total)
# Out:
# 165

# %%
a <=b and c <= b

# %%
a == 5 or a == 8
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_20891/1109951203.py in <cell line: 0>()
# ----> 1 a == 5 or 8
#
# NameError: name 'a' is not defined

# %%
1 < a < 10 and a != 5

# %%
scores = [65, 80, 40, 92, 76, 52]
count = 0
for i in scores:
  if i > 60:
    count += 1
  else:
    continue
print(count)
# Out:
# 4

# %%
year = 2021
month = 4
day = 10
message = '今日は{}年{}月{}日です'.format(year, month, day)
print(message)
# Out:
# 今日は2021年4月10日です

# %%
year = 2021
month = 4
day = 10
message = '今日は{1}月{2}日です。西暦{0}年です。'.format(year, month, day)
print(message)
# Out:
# 今日は4月10日です。西暦2021年です。

# %%
'1/3 = {:.3f}'.format(1/3)
# Out:
# '1/3 = 0.333'

# %%
'{:,}円'.format(1000000)
# Out:
# '1,000,000円'

# %%
'{:>5}'.format(123)
# Out:
# '  123'

# %%
'cat' in 'catch'
# Out:
# True

# %%
a = [10, 20, 30, 40]
a.append(50)
a
# Out:
# [10, 20, 30, 40, 50]

# %%
a.insert(0, 0)
a
# Out:
# [0, 10, 20, 30, 40, 50]

# %%
a.remove(0)
a
# Out:
# [10, 20, 30, 40, 50]

# %%
a.pop()
a
# Out:
# [10, 20, 30, 40]

# %%
a.clear()
a
# Out:
# []

# %%
a = [10, 20, 30, 40]
a.index(20)
# Out:
# 1

# %%
a.count(10)
# Out:
# 1

# %%
a.reverse()
a
# Out:
# [40, 30, 20, 10]

# %%
a = [10, 20, 30, 40]
del a [1]
a
# Out:
# [10, 30, 40]

# %%
a = a + [0, 1]
a
# Out:
# [10, 30, 40, 0, 1]

# %%
2 in a
# Out:
# False

# %%
len(a)
# Out:
# 5

# %%
sorted(a)
# Out:
# [0, 1, 10, 30, 40]

# %%
sorted(a, reverse=True)
# Out:
# [40, 30, 10, 1, 0]

# %%
date = [2**n for n in range(1,11)]
date
# Out:
# [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]

# %%
[str(n) + '月' for n in range(1, 13)]
# Out:
# ['1月', '2月', '3月', '4月', '5月', '6月', '7月', '8月', '9月', '10月', '11月', '12月']

# %%
data0 = ['apple', 'orange', 'banana', 'avocado']
data1 = [s for s in data0 if s[0] == 'a']
print(data1)
# Out:
# ['apple', 'avocado']

# %%
a = [1, 2, 3, 4]
a
a[0]
a[0] = 99
a
# Out:
# [99, 2, 3, 4]

# %%
a = 1, 2, 3, 4
a
# Out:
# (1, 2, 3, 4)

# %%
info = {'firstname':'太郎','lastname':'山田','address':'茨城県つくば市 99-99'}
info['firstname']
# Out:
# '太郎'

# %%
info.get('firstname')
# Out:
# '太郎'

# %%
info.get('tel')

# %%
info ['tel'] = '090 - 000 - 0000'

# %%
info.get('tel')
# Out:
# '090 - 000 - 0000'

# %%
del info['tel']
len(info)
# Out:
# 3

# %%
'age' in info
# Out:
# False

# %%
'firstname' in info
# Out:
# True

# %%
data = {'b':5, 'c':2, 'a':8, 'd':7}
print(sorted(data.items()))
# Out:
# [('a', 8), ('b', 5), ('c', 2), ('d', 7)]

# %%
data = {'b':5,'c':2,'a':8,'d':7}
print(sorted(data.items(),key=lambda x:x[1]))
# Out:
# [('c', 2), ('b', 5), ('d', 7), ('a', 8)]

# %%
data = [1,2,3]
a = set(data)
a
# Out:
# {1, 2, 3}

# %%
set1 = {'A', 'B', 'C'}
set2 = {'B', 'C'}
set1.issubset(set2)
# Out:
# False

# %%
def is_positive(i):
  return i > 0
a = -10
if is_positive(a):
  print('aの値は正です')
else:
  print('aの値は負またはゼロです')
# Out:
# aの値は負またはゼロです

# %%
def get_two_numbers():
  return(2, 3)
a, b = get_two_numbers()
print(a, b)
# Out:
# 2 3

# %%
def print_price(price, func):
  print('価格は' + func(price))
def price_without_tax(price):
  return f'税抜き{price}円'
def price_with_tax(price):
  return f'税込み{int(price*1.1)}円'
print_price(800,price_without_tax)
print_price(800,price_with_tax)
# Out:
# 価格は税抜き800円
# 価格は税込み880円

# %%
def func(a,b = 5):
  print(a, b)

# %%
func(5)
# Out:
# 5 5

# %%
func(5, 10)
# Out:
# 5 10

# %%
func(a = 5)
# Out:
# 5 5

# %%
func(5, b = 10)
# Out:
# 5 10

# %%
def print_hello(count):
  for count in range(0, count):
    print('Hello')
print_hello(3)
# Out:
# Hello
# Hello
# Hello

# %%
def get_rectangle_area(width,height):
  return width * height
print(get_rectangle_area(10, 5))
# Out:
# 50

# %%
def get_message(name = '名無し'):
  return f'こんにちは{name}さん'
print(get_message())
print(get_message('山田'))
# Out:
# こんにちは名無しさん
# こんにちは山田さん

# %%
def get_tail(*args):
  return args[-1]
print(get_tail(3, 5, 9, 2))
# Out:
# 2

# %%
for k in info.keys():
  print(k)
# Out:
# firstname
# lastname
# address

# %%
for v in info.values():
    print(v)
# Out:
# 太郎
# 山田
# 茨城県つくば市 99-99

# %%
for i in info.items():
  print(i)
# Out:
# ('firstname', '太郎')
# ('lastname', '山田')
# ('address', '茨城県つくば市 99-99')
