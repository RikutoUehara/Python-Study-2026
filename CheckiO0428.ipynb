# %% [markdown]
# <a href="https://colab.research.google.com/github/RikutoUehara/Python-Study-2026/blob/main/CheckiO0428.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Declaring variable and setting their values
cyborgs = 10
# write your code here
robots = 2
droids = 5

# 2. Setting values for variables in a single line
# write your code here
robots, droids = 2, 5

# 3. Declaring with type annotation
cyborgs: int = 10
# write your code here
robots: int = 2
droids: int = 5
